# %% [markdown]
# Mount your drive to run file.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Compile the GaussSeidel.cu file and run the complied file. The results will be saved as text. </br>
# After mounting to Google Drive, you can find the directory to code folder by clicking on the folder symbol on the left side bar. Your Google Drive will directory is ``` ./drive/MyDrive ``` </br>
# The following command is based on our Google Drive directory, you might need to change a little bit by your Drive structure.

# %%
# !mkdir -p ./results/CUDA

# %%
# !nvcc -o /content/GaussSeidel_CUDA /content/drive/MyDrive/Parallel\ Programming/Capstone\ Project/GaussSeidel.cu
# !./GaussSeidel_CUDA
# Out:
# /content/drive/MyDrive/Parallel Programming/Capstone Project/GaussSeidel.cu(198): warning: conversion from a string literal to "char *" is deprecated
#
# /content/drive/MyDrive/Parallel Programming/Capstone Project/GaussSeidel.cu(198): warning: conversion from a string literal to "char *" is deprecated

# %% [markdown]
# Run file text_to_imgage.py file to convert result in text to image.

# %%
# !python /content/drive/MyDrive/Parallel\ Programming/Capstone\ Project/text_to_image.py
# Out:
# OK

# %% [markdown]
# Run file create_gif.py to create gif for diffusion process.

# %%
# !python /content/drive/MyDrive/Parallel\ Programming/Capstone\ Project/create_gif.py
# Out:
# OK

# %% [markdown]
# Run file display.py if you want to display process in some iterations.

# %%
# !python /content/drive/MyDrive/Parallel\ Programming/Capstone\ Project/display.py
# Out:
# <Figure size 1200x300 with 4 Axes>
# OK

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os

if not os.path.isdir('./results/images/'):
  os.system('mkdir ./results/images/')

path = "./results/images"
img_names = ['00000.png', '00500.png', '01500.png', '11090.png']

fig, axes = plt.subplots(1, 4)
fig.set_size_inches(16, 4)
axes[0].set_title("Original state")
axes[1].set_title("Iteration 500")
axes[2].set_title("Iteration 1500")
axes[3].set_title("Final state")

for i, name in enumerate(img_names):
    img = cv2.imread(os.path.join(path, name))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    axes[i].imshow(img)
    axes[i].set_axis_off()

plt.show()
